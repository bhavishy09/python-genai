# %% [markdown]
# ### 8-parts of speech tagging

# %%
import nltk

# download tagger if you haven't already
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/bhavishyakatariya/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/bhavishyakatariya/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
print(nltk.pos_tag("bhavishya is student in jiit third year".split()))
# Out:
# [('bhavishya', 'NN'), ('is', 'VBZ'), ('student', 'VBN'), ('in', 'IN'), ('jiit', 'NN'), ('third', 'JJ'), ('year', 'NN')]
