# %%
import pandas as pd 
messages=pd.read_csv('smsspamcollection.txt',sep='\t' ,names=["label","message"])
import re
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

ps=PorterStemmer()

corpus=[]
## remove special char --> lower down-->apply stopword -->stemming 

for i in range(0,len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[ps.stem(word) for word in review if not word in stopwords.words('english')]
    review=' '.join(review)
    corpus.append(review)
  ## create bag of words model

from sklearn.feature_extraction.text import CountVectorizer

### like take to 2500 words fromm vocab 
cv=CountVectorizer(max_features=100,binary=True,ngram_range=(1,3)) 
x=cv.fit_transform(corpus).toarray()

# %%
cv.vocabulary_
# Out:
# {'point': np.int64(32),
#  'point crazi': np.int64(33),
#  'point crazi avail': np.int64(34),
#  'ok': np.int64(21),
#  'wif': np.int64(96),
#  'oni': np.int64(24),
#  'ok lar': np.int64(22),
#  'wif oni': np.int64(97),
#  'ok lar joke': np.int64(23),
#  'free': np.int64(2),
#  'win': np.int64(98),
#  'st': np.int64(82),
#  'receiv': np.int64(46),
#  'st may': np.int64(83),
#  'receiv entr': np.int64(47),
#  'st may text': np.int64(84),
#  'say': np.int64(59),
#  'say earli': np.int64(60),
#  'say earli hor': np.int64(61),
#  'nah': np.int64(9),
#  'nah think': np.int64(10),
#  'nah think goe': np.int64(11),
#  'week': np.int64(91),
#  'word': np.int64(99),
#  'like': np.int64(3),
#  'week word': np.int64(94),
#  'week word back': np.int64(95),
#  'speak': np.int64(79),
#  'aid': np.int64(0),
#  'patent': np.int64(28),
#  'speak treat': np.int64(80),
#  'speak treat like': np.int64(81),
#  'per': np.int64(29),
#  'request': np.int64(51),
#  'oru': np.int64(25),
#  'nurungu': np.int64(18),
#  'set': np.int64(71),
#  'per request': np.int64(30),
#  'request mell': np.int64(52),
#  'oru minnaminungint': np.int64(26),
#  'nurungu vettam': np.int64(19),
#  'set callertu': np.int64(72),
#  'per request mell': np.int64(31),
#  'request mell mell': np.int64(53),
#  'oru minnaminungint nurungu': np.int64(27),
#  'nurungu vettam set': np.int64(20),
#  'network': np.int64(12),
#  'select': np.int64(65),
#  'receivea': np.int64(48),
#  'prize': np.int64(38),
#  'reward': np.int64(54),
#  'claim': np.int64(1),
#  'network custom': np.int64(13),
#  'select receivea': np.int64(66),
#  'receivea prize': np.int64(49),
#  'prize reward': np.int64(41),
#  'reward claim': np.int64(55),
#  'network custom select': np.int64(14),
#  'select receivea prize': np.int64(67),
#  'receivea prize reward': np.int64(50),
#  'prize reward claim': np.int64(42),
#  'month': np.int64(6),
#  'mobil month': np.int64(4),
#  'month entitl': np.int64(7),
#  'mobil month entitl': np.int64(5),
#  'month entitl updat': np.int64(8),
#  'soon': np.int64(76),
#  'soon want': np.int64(77),
#  'stuff anymor': np.int64(85),
#  'soon want talk': np.int64(78),
#  'stuff anymor tonight': np.int64(86),
#  'six': np.int64(73),
#  'pound': np.int64(35),
#  'txt': np.int64(87),
#  'send': np.int64(68),
#  'six chanc': np.int64(74),
#  'pound txt': np.int64(36),
#  'send cost': np.int64(69),
#  'six chanc win': np.int64(75),
#  'pound txt csh': np.int64(37),
#  'send cost day': np.int64(70),
#  'week free': np.int64(92),
#  'prize jackpot': np.int64(39),
#  'week free membership': np.int64(93),
#  'prize jackpot txt': np.int64(40),
#  'search': np.int64(62),
#  'right': np.int64(56),
#  'promis': np.int64(43),
#  'search right': np.int64(63),
#  'right word': np.int64(57),
#  'promis wont': np.int64(44),
#  'search right word': np.int64(64),
#  'right word thank': np.int64(58),
#  'promis wont take': np.int64(45),
#  'wap': np.int64(88),
#  'next': np.int64(15),
#  'wap link': np.int64(89),
#  'next txt': np.int64(16),
#  'wap link next': np.int64(90),
#  'next txt messag': np.int64(17)}
