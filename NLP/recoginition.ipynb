# %% [markdown]
# ### named entity recoginition
#
# sentences=" the tower was built 1999 to 2004 by french engineer"
#
# person eg: bhavishya
#
# place or location eg: india
#
# date eg:sept ,24-09-1998
#
# Time EG:4:40 PM
#
# MONEY : 1 billon dollar

# %%
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /Users/bhavishyakatariya/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
import nltk

sentence = "the tower was built 1999 to 2004 by french engineer"
words = nltk.word_tokenize(sentence)
tag_elements = nltk.pos_tag(words)

nltk.ne_chunk(tag_elements).draw()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 7
#       4 words = nltk.word_tokenize(sentence)
#       5 tag_elements = nltk.pos_tag(words)
# ----> 7 nltk.ne_chunk(tag_elements).draw()
#
# File ~/Library/Python/3.9/lib/python/site-packages/nltk/chunk/__init__.py:192, in ne_chunk(tagged_tokens, binary)
#     190     chunker = ne_chunker(fmt="binary")
#     191 else:
# --> 192     chunker = ne_chunker()
#     193 return chunker.parse(tagged_tokens)
#
# File ~/Library/Python/3.9/lib/python/site-packages/nltk/chunk/__init__.py:174, in ne_chunker(fmt)
#     170 def ne_chunker(fmt="multiclass"):
#     171     """
#     172     Load NLTK's currently recommended named entity chunker.
#     173     """
# --> 174     return Maxent_NE_Chunker(fmt)
#
# File ~/Library/Python/3.9/lib/python/site-packages/nltk/chunk/named_entity.py:330, in Maxent_NE_Chunker.__init__(self, fmt)
#     328 self._fmt = fmt
#     329 self._tab_dir = find(f"chunkers/maxent_ne_chunker_tab/english_ace_{fmt}/")
# --> 330 self.load_params()
#
# File ~/Library/Python/3.9/lib/python/site-packages/nltk/chunk/named_entity.py:335, in Maxent_NE_Chunker.load_params(self)
#     332 def load_params(self):
#     333     from nltk.classify.maxent import BinaryMaxentFeatureEncoding, load_maxent_params
# --> 335     wgt, mpg, lab, aon = load_maxent_params(self._tab_dir)
#     336     mc = MaxentClassifier(
#     337         BinaryMaxentFeatureEncoding(lab, mpg, alwayson_features=aon), wgt
#     338     )
#     339     self._tagger = NEChunkParserTagger(classifier=mc)
#
# File ~/Library/Python/3.9/lib/python/site-packages/nltk/classify/maxent.py:1565, in load_maxent_params(tab_dir)
#    1564 def load_maxent_params(tab_dir):
# -> 1565     import numpy
#    1567     from nltk.tabdata import MaxentDecoder
#    1569     mdec = MaxentDecoder()
#
# ModuleNotFoundError: No module named 'numpy'
