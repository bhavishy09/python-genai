# %%
corpus=""" hello i m bhaishya ,currently i m learing nlp.
and want make my minor project .
"""

print(corpus)
# Out:
#  hello i m bhaishya ,currently i m learing nlp.
# and want make my minor project .

# %%
## TOKENIZATION
## paragraphs --> sentences 


from nltk.tokenize import sent_tokenize


print(sent_tokenize(corpus))
# Out:
# ['Hello I am Bhavishya.', 'Currently I am learning NLP.', 'I want to make my minor project.']

# %%
##tokenization paragraph into words 

from nltk.tokenize import word_tokenize
print(word_tokenize(corpus))
# Out:
# ['Hello', 'I', 'am', 'Bhavishya', '.', 'Currently', 'I', 'am', 'learning', 'NLP', '.', 'I', 'want', 'to', 'make', 'my', 'minor', 'project', '.']

# %%
document=sent_tokenize(corpus)
for sentences in document:
    print(word_tokenize(sentences))
# Out:
# ['Hello', 'I', 'am', 'Bhavishya', '.']
# ['Currently', 'I', 'am', 'learning', 'NLP', '.']
# ['I', 'want', 'to', 'make', 'my', 'minor', 'project', '.']

# %%
## 1 more library 
from nltk.tokenize import wordpunct_tokenize
print(wordpunct_tokenize(corpus))
# Out:
# ['Hello', 'I', 'am', 'Bhavishya', '.', 'Currently', 'I', 'am', 'learning', 'NLP', '.', 'I', 'want', 'to', 'make', 'my', 'minor', 'project', '.']

# %%
## tree ba
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'I',
#  'am',
#  'Bhavishya.',
#  'Currently',
#  'I',
#  'am',
#  'learning',
#  'NLP.',
#  'I',
#  'want',
#  'to',
#  'make',
#  'my',
#  'minor',
#  'project',
#  '.']
