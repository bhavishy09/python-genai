# %%
## basic syntax rules in python 
## casesensity -->pyhton yes 

name="bhavishya"
Name="katariya"
print(name)
print(Name)
# Out:
# bhavishya
# katariya

# %%
##indentation--> to define blocks of code. consistent use of spaces (commonly 4) or a tab is required 
age=30
if age>23:
    print(age)

print(age)
# Out:
# 30
# 30

# %%
##line continuation--> use a  backslash (\)to continue a statement to next line 
total=1+2+3+4+5+5+5+5+\
4+4+4

print(total)
# Out:
# 42

# %%
x = 3; y = 4; z = x + y
print(z)
# Out:
# 7

# %%
## understand semnatics in python 
#variable assignments 

age=32 ##age
name="bhavishya"

# %%
type(age)
# Out:
# int

# %%
## Type Inference
variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
if True:
    print("Correct Indentation")
    if False:
        print("This ont print")
        
    print("This will print")
print("Outside the if block")
# Out:
# Correct Indentation
# This will print
# Outside the if block
